# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

# %%
url = "https://www.saramin.co.kr/zf_user/"
html = requests.get(url).text
soup = BeautifulSoup(html, 'lxml')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <title>내일이 더 즐거운 사람인 | 구인구직, 채용, 취업플랫폼</title> <meta content="ko-KR" http-equiv="Content-Language"/>
# <meta content="app-id=739013038" name="apple-itunes-app"/>
# <meta content="내일이 더 즐거운 사람인에서 AI채용추천, 기업정보, 연봉정보, 면접후기 등 취업, 채용에 꼭 필요한 서비스를 만나보세요." name="Description"/>
# <meta content="사람인" name="writer"/>
# <meta content="취업, 채용, 구인, 구직, 일자리, 취업정보, 취업사이트, 채용플랫폼, 채용공고, 채용정보, 기업정보, 연봉정보, 공채, 면접, 기업리뷰, 이직, 이력서, 사람인, saramin" name="keywords"/>
# <meta content="nosublinks" name="naver"/>
# <meta content="width=1280" name="viewport"/>
# <meta content="IE=Edge;" http-equiv="X-UA-Compatible"/><meta content="https://www.saramin.co.kr/zf_user/" property="og:url"/>
# <meta content="사람인 - 내일이 더 즐거운 취업플랫폼" property="og:title"/>
# <meta content="내일이 더 즐거운 사람인 | AI채용추천, 기업정보, 연봉정보, 면접후기 등 취업에 꼭 필요한 서비스를 만나보세요." property="og:description"/>
# <meta content="//www.saraminimage.co.kr/logo/saraminsnslogo.png" property="og:image"/>
# ...

# %%
driver = webdriver.Chrome(service=Service('driver/chromedriver'))
driver.get(url) # - 사람인 사이트 크롬 접속
time.sleep(2)

# %%
xpath = """//*[@id="sri_header"]/div[1]/div[1]/div[1]/ul/li[1]/a"""
driver.find_element(By.XPATH, xpath).click() # - 지역별 선택

# %%
xpath = """//*[@id="sri_header"]/div[1]/div[1]/div[2]/ul/li[2]/a"""
driver.find_element(By.XPATH, xpath).click() # - 지역별 -> 직업별( 직무 )

# %%
xpath="""//*[@id="sp_main_wrapper"]/div[1]/div[1]/button"""
driver.find_element(By.XPATH, xpath).click()  #  경력 선택창 열기.
time.sleep(1)

# %%
xpath="""//*[@id="sp_main_wrapper"]/div[1]/div[1]/div/div[1]/div[1]/label"""
driver.find_element(By.XPATH, xpath).click()  # 경력을 신입으로 선택
time.sleep(1)

# %%
xpath="""//*[@id="sp_main_wrapper"]/div[1]/div[1]/div/div[3]/button[2]"""
driver.find_element(By.XPATH, xpath).click()  # 경력 선택창 닫기.
time.sleep(2)

# %%
xpath="""//*[@id="job_category_ipt_keyword"]"""
driver.find_element(By.XPATH, xpath).click()  # 직업 입력창 클릭
time.sleep(2)

# %%
query_txt = 'python'
element = driver.find_element_by_id("job_category_ipt_keyword")
element.send_keys(query_txt)
time.sleep(2) # 직업 입력창에 파이썬을 검색
# Out:
# E:\T\bit/ipykernel_8132/3672696063.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   element = driver.find_element_by_id("job_category_ipt_keyword")

# %%
xpath="""//*[@id="autocomplete_has_result"]/div[1]/div[2]/div/ul/li[1]/div/label"""
driver.find_element(By.XPATH, xpath).click() 
time.sleep(2) # 파이썬 선택

# %%
xpath="""//*[@id="sp_main_wrapper"]/div[2]/ul/li[2]/button/span[1]"""
driver.find_element(By.XPATH, xpath).click()  
time.sleep(1) #지역 선택

# %%
xpath="""//*[@id="sp_area_lastDepth_101000"]/li[1]/div/label"""
driver.find_element(By.XPATH, xpath).click()  
time.sleep(1) #서울전체 선택

# %%
xpath="""//*[@id="depth1_btn_102000"]/button"""
driver.find_element(By.XPATH, xpath).click()  
time.sleep(1)  #경기전체 선택

# %%
xpath="""//*[@id="search_btn"]"""
driver.find_element(By.XPATH, xpath).click()  # 선택된 건수 검색하기
